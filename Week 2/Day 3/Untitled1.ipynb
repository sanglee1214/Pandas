# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
# %matplotlib notebook

# %%
df = pd.DataFrame(np.random.randn(10,4),columns = ['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.924363 -1.007867 -0.569252 -0.004691
# 1  0.434084  0.639816  0.721877  0.077748
# 2  0.600508 -2.401051  2.318295  0.971240
# 3  0.705958 -0.634687 -1.213760 -0.881668
# 4 -1.817003  0.206741  0.488442 -0.038631
# 5 -0.538417  0.194017  0.500176 -2.604071
# 6 -0.170352 -0.015998 -1.392670 -0.930871
# 7 -1.227243 -0.425664 -0.428698  0.916028
# 8 -1.903281 -0.827603  1.634533 -0.022659
# 9  0.030522  1.058423  1.943157  1.433991

# %%
df.plot.scatter(x = 'a', y = 'b', s = df['b']*120, color = 'b', label = 'Interaction between a and b', title = 'My Title\n')
# Out:
# <img src="data:image/png;base64,...">

# %%
df.plot.bar(stacked = True)
# Out:
# <img src="data:image/png;base64,...">
