# %% [markdown]
# # Plotting the Housing Data
#
# A good first step when working with any new data set is to do some exploratory data analysis, starting with a plots of the data. Let's download the data. There is some information about the [data set](https://archive.ics.uci.edu/ml/datasets/Housing) at the UCI ML repository. It's a good idea to take a look at the dataset description before proceeding.

# %%
# %matplotlib inline

# Download the data, save to a file called "housing.data"
import urllib
data_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data"
urllib.urlretrieve (data_url, "housing.data")
# Out:
# ('housing.data', <httplib.HTTPMessage instance at 0x109cb8638>)

# %% [markdown]
# The data file does not contain the column names in the first line, so we'll need to add those in manually. You can find the names and explanations [here](https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.names). We've extracted the names below for convenience.

# %%
names = ["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE",
         "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT", "MEDV"]

# %% [markdown]
# ## Loading the Data
#
# Now let's use pandas to load the data into a data frame. Note that the data is space separated (rather than the more common comma separated data). Here are the first few lines:
#
# ```
# 0.00632  18.00   2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  15.30 396.90   4.98  24.00
# 0.02731   0.00   7.070  0  0.4690  6.4210  78.90  4.9671   2  242.0  17.80 396.90   9.14  21.60
# ```

# %%
import pandas as pd

data = pd.read_csv("housing.data", header=None, names=names, delim_whitespace=True)

# Take a look at the first few rows
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# ### Knowledge Check:
#
# How many rows are in the dataset?

# %%
# Compute the number of rows
data.count()
# Out:
# CRIM       506
# ZN         506
# INDUS      506
# CHAS       506
# NOX        506
# RM         506
# AGE        506
# DIS        506
# RAD        506
# TAX        506
# PTRATIO    506
# B          506
# LSTAT      506
# MEDV       506
# dtype: int64

# %% [markdown]
# ## Plotting the Data
#
# We are interested in the house values, given in column "MEDV" as a target for modeling. By plotting each of the other columns against "MEDV" we can get a sense of which variables may be correlated.
#
# There are many ways we can plot the data, using `pandas`, `matplotlib`, or `seaborn`. In any case, it's nice to import `seaborn` for the improved styling. Let's try using `pandas` first to make a scatter plot of crime (column "CRIM") versus house value ("MEDV").

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Plot using pandas
data.plot.scatter(x='CRIM', y='MEDV')

# %% [markdown]
# It looks like there is a relationship. While houses in low crime areas can have a wide range of values, houses in high crime areas appear to have lower values.
#
# Knowledge checks:
# * How do we select a column of data from a pandas DataFrame?
# * Let's make the same plot with matplotlib.

# %%
# Knowledge Check Solution
from matplotlib import pyplot as plt

# Plot using matplotlib
plt.scatter(data["CRIM"], data["MEDV"])
plt.xlabel("Crime")
plt.ylabel("House Value")

# %% [markdown]
# ### Exercises
#
# Exercise 1: Using `pandas` or `matplotlib` plot the remaining variables against "MEDV" and discuss the relationships you find. Question: Which variables seem to correlate well?
#
# ### Bonus Exercises
#
# Exercise 2: Seaborn is very handy for making plots of data for exploratory purposes. Try using `seaborn`'s [pairplots](https://stanford.edu/~mwaskom/software/seaborn/examples/scatterplot_matrix.html) to make similar plots.
#
# Exercise 3: Improve your plots by including units and better axis labels. You'll need to read the [data set description](https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.names).
#
# Exercise 4: Can you find any visual correlations between two variables other than MEDV?

# %%
#"CRIM       506
#ZN         506
#INDUS      506
#CHAS       506
#NOX        506
#RM         506
#AGE        506
#DIS        506
#RAD        506
#TAX        506
#PTRATIO    506
#B          506
#LSTAT      506
#MEDV       506
#fig = plt.figure()
#axes = fig.gca()
#axes.set_xlabel('MEDV')
#axes.set_ylabel('House Value')
#plt.scatter(data["MEDV"], data["LSTAT"])

#fig1 = plt.figure()
#axes = fig1.gca()
#axes.set_xlabel('MEDV')
#axes.set_ylabel('ZN')
#plt.scatter(data["MEDV"], data["ZN"])

#fig2 = plt.figure(figsize=(8,8))
#axes = fig2.gca()
#axes.set_title('Correlation between Participation Rate and Math',fontsize = 20)
#axes.set_xlabel('Rate', fontsize = 16)
#axes.set_ylabel('Math Scores', fontsize = 16)
#plt.scatter(noStateDict['rateColumn'],noStateDict['mathColumn'], c='darkred')
from pandas.tools.plotting import scatter_matrix
scatter_matrix(data, alpha=0.2, figsize=(25, 25), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12cc50d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13a40c310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13a4d5c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13a696710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13a670b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13a6e3590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b842710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13b1d0590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b900190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b978710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13b18ae10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13b2a1050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13b308f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13b37a150>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x13b3f10d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13b44d110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13b4c6090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13b459b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13b6ba150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13c0370d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13c098b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13c11abd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13c17dc10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13c1fdc90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13c30dc10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13c3eed10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13c571c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13c5d3ed0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x13c655e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13c6bcc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13c744e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13c7c7dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13c935950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13c9b98d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13ca1da10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13ca9ca90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13caace50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13cc8ea50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13cd109d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13cd75cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13cdf6c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13ce5ea50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x13cee7c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d067bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d0d7690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d159610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d1be750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d23e7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d277890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d42e790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d4b0710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d514a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d596990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d5fd790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d685990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d809910>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x13d8773d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d8fa350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d95e490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13d9e0510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13db1a5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13dbcf4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13dc54450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13dcb8750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13dd3a6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13dda14d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13df2b6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13dfad650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13e01c110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13e09f090>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x13e2021d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13e283250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13e2bc310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13e375210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13e3f7190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13e45b490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13e4dd410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13e644210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13e6ce410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13f051390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13f0b2e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13f135d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13f18eed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13f21cf50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x13f261050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13f40af10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13f48ee90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13f4ff1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13f582150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13f5dbf10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13f774150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13f7f60d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13f857b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13f8d8ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13f93dc10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13f9bec90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13f9cdc10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13faafc50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x13fc31bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13fc94ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13fe15e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13fe80c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13fea95d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13ff2b290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13ffd91d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x14005b9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1400c1510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x140241590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1402c5510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x140331810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1403b4790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x140524310>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1405a4b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x140609650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x14068b6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x14070e650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x14077c950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1407fb8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x14116e450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1411edc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x141245790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1412d3810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x141459790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1414c5a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x141549a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1415b7590>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x141637d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1416918d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x14171e950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1417a18d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x141a0ebd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x141a91b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x141b016d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x141b82ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x141bdaa10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x141c68a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x141ceca10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x141d58d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x141ddac90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x141e4a810>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x141ed8050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x142025b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1420b0bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x142136b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1421a1e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x142326dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x142396950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x142524190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x142570c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1425fbd10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x14267ec90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1426edf90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x14276ff10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1427dea90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x14306b2d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1430b8dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x143245e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1432c8dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x143444110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1434c7090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x143527bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1435b7410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x143604f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x143690f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x143713f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x14378d250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1439111d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x143973d10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x143b01550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x143b66090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x143be7110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x143c6b090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x143cd8390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x143d5b310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x143dbce50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x143f49690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x143faf1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x14402f250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1440b41d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x14411f4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1441a3450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x144305f90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1443927d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1443f9310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x144479390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1444fe310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x14466c610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1446ed590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x14475d110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1447de910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x144843450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1448c44d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x144a48450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x144ab4750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x144b386d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x144ba6250>]], dtype=object)
