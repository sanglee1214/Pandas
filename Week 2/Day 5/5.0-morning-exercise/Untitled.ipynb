# %%
import pandas as pd
import numpy as np
path ="2016-FCC-New-Coders-Survey-Data.csv"
#data = pd.DataFrame.from_csv(path)
df = pd.read_csv(path)
print df
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0      28.0               0.0             NaN                   NaN
# 1      22.0               0.0             NaN                   NaN
# 2      19.0               0.0             NaN                   NaN
# 3      26.0               0.0             NaN                   NaN
# 4      20.0               0.0             NaN                   NaN
# 5      34.0               0.0             NaN                   NaN
# 6      23.0               0.0             NaN                   NaN
# 7      35.0               0.0             NaN                   NaN
# 8      33.0               0.0             NaN                   NaN
# 9      33.0               0.0             NaN                   NaN
# 10     57.0               0.0             NaN                   NaN
# 11     23.0               0.0             NaN                   NaN
# 12     47.0               0.0             NaN                   NaN
# ...

# %%
newDF = df.fillna(0)
newDF.describe()
# Out:
#                 Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# count  15620.000000      15620.000000    15620.000000          15620.000000
# mean      25.426697          0.061012        0.041165              0.023752
# std       12.891613          0.239359        0.198678              0.152279
# min        0.000000          0.000000        0.000000              0.000000
# 25%       21.000000          0.000000        0.000000              0.000000
# 50%       26.000000          0.000000        0.000000              0.000000
# 75%       32.000000          0.000000        0.000000              0.000000
# max       86.000000          1.000000        1.000000              1.000000
#
#        BootcampLoanYesNo  BootcampMonthsAgo  BootcampPostSalary  \
# count       15620.000000       15620.000000        15620.000000
# mean            0.019910           0.365813         1346.630410
# std             0.139697           3.156297         9932.221941
# ...
