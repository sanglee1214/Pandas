# %% [markdown]
# # Web Scraping for Indeed.com & Predicting Salaries

# %% [markdown]
# In this project, we will practice two major skills: collecting data by scraping a website and then building a binary predictor with Logistic Regression.
#
# We are going to collect salary information on data science jobs in a variety of markets. Then using the location, title and summary of the job we will attempt to predict the salary of the job. For job posting sites, this would be extraordinarily useful. While most listings DO NOT come with salary information (as you will see in this exercise), being to able extrapolate or predict the expected salaries from other listings can help guide negotiations.
#
# Normally, we could use regression for this task; however, we will convert this problem into classification and use Logistic Regression.
#
# - Question: Why would we want this to be a classification problem?
# - Answer: While more precision may be better, there is a fair amount of natural variance in job salaries - predicting a range be may be useful.
#
# Therefore, the first part of the assignment will be focused on scraping Indeed.com. In the second, we'll focus on using listings with salary information to build a model and predict additional salaries.

# %% [markdown]
# ### Scraping job listings from Indeed.com

# %% [markdown]
# We will be scraping job listings from Indeed.com using BeautifulSoup. Luckily, Indeed.com is a simple text page where we can easily find relevant entries.
#
# First, look at the source of an Indeed.com page: (http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10")
#
# Notice, each job listing is underneath a `div` tag with a class name of `result`. We can use BeautifulSoup to extract those.

# %% [markdown]
# #### Setup a request (using `requests`) to the URL below. Use BeautifulSoup to parse the page and extract all results (HINT: Look for div tags with class name result)

# %%
URL = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=0"

# %%
import requests
import bs4
from bs4 import BeautifulSoup
import urllib2
import pandas as pd
import numpy as np

# %%
## YOUR CODE HERE

page = urllib2.urlopen(URL)

#parse the page
soup = BeautifulSoup(requests.get(URL).text)

#extracting all results
result = soup.find("div", {"class": "row result"},'lxml')

# %% [markdown]
# Let's look at one result more closely. A single `result` looks like
#
# ```
# <div class=" row result" data-jk="2480d203f7e97210" data-tn-component="organicJob" id="p_2480d203f7e97210" itemscope="" itemtype="http://schema.org/JobPosting">
# <h2 class="jobtitle" id="jl_2480d203f7e97210">
# <a class="turnstileLink" data-tn-element="jobTitle" onmousedown="return rclk(this,jobmap[0],1);" rel="nofollow" target="_blank" title="AVP/Quantitative Analyst">AVP/Quantitative Analyst</a>
# </h2>
# <span class="company" itemprop="hiringOrganization" itemtype="http://schema.org/Organization">
# <span itemprop="name">
# <a href="/cmp/Alliancebernstein?from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=2480d203f7e97210&amp;jcid=b374f2a780e04789" target="_blank">
#     AllianceBernstein</a></span>
# </span>
# <tr>
# <td class="snip">
# <nobr>$117,500 - $127,500 a year</nobr>
# <div>
# <span class="summary" itemprop="description">
# C onduct quantitative and statistical research as well as portfolio management for various investment portfolios. Collaborate with Quantitative Analysts and</span>
# </div>
# </div>
# </td>
# </tr>
# </table>
# </div>
# ```
#
# While this has some more verbose elements removed, we can see that there is some structure to the above:
# - The salary is available in a `nobr` element inside of a `td` element with `class='snip`.
# - The title of a job is in a link with class set to `jobtitle` and a `data-tn-element="jobTitle`.
# - The location is set in a `span` with `class='location'`.
# - The company is set in a `span` with `class='company'`.

# %% [markdown]
# ### Write 4 functions to extract each item: location, company, job, and salary.
#
# example:
# ```python
# def extract_location_from_result(result):
#     return result.find ...
# ```
#
#
# - Make sure these functions are robust and can handle cases where the data/field may not be available.
# - Test the functions on the results above

# %% [markdown]
# ## YOUR CODE HERE
# def extract_location_from_result(result):
#     for loc in soup.findAll('span', {'class':'location'}):
#         return loc.get_text(strip=True)
#
# def extract_company_from_result(result):
#     for loc in soup.findAll('span', {'class':'company'}):
#         return loc.get_text(strip=True)
#
# salary = []
#
# def extract_salary_from_result(result):
#     for loc in soup.findAll('span', {'class': 'location'}):
#         Sibling = soup.findNextSiblings('div')
#         if Sibling != None:
#             salary.append(loc.text.strip())
#         else:
#             salary.append(np.nan)
#
# def extract_title_from_result(result):
#     for loc in soup.findAll('a', {'data-tn-element':'jobTitle'}):
#         return loc['title']
#
# #print extract_title_from_result(result)

# %%
#def extract_text(el):
#    if el:
#        return el.text.strip()
#    else:
#        return ''
        
def extract_company_from_result(result):
    return result.find('span', {'class' : 'company'}).text.strip()

def extract_location_from_result(result):
    return  result.find('span', {'class' : 'location'}).text.strip()

#def extract_summary_from_result(result):
#    return  extract_text(result.find('span', {'class' : 'summary'}))

def extract_title_from_result(result):
    return result.find('a', {'data-tn-element' : 'jobTitle'}).text.strip()

def extract_salary_from_result(result):
    salary_table = result.find('td', {'class' : 'snip'})
    if salary_table:
        snip = salary_table.find('nobr')
        if snip:
            return snip.text.strip()
        else:
            return np.nan
        
#print extract_salary_from_result(result)

# %%
lst1 = [loc.get_text(strip=True) for loc in soup.findAll('span', {'class':'company'})]
print (lst1)

lst2 = [loc.get_text(strip=True) for loc in soup.findAll('span', {'class':'location'})]
print (lst2)

lst3 = [loc.get_text(strip=True) for loc in soup.findAll('a', {'data-tn-element':'jobTitle'})]#dual conditions?
print (lst3)

#lst3 = [loc.findNextSibling('div') for loc in soup.findAll('div', {'class':'sjcl'})]
#print (lst3)
# Out:
# [u'Uber', u'Princeton Consulting', u'State Street', u'S&P Global Ratings', u'Bloomberg', u'Bloomberg', u'AllianceBernstein', u'eTemp', u'Verizon', u'IPG Mediabrands', u'MLB Advanced Media', u'Music Choice', u'NBCUniversal', u'New York University College of Dentistry', u'AbilTo, Inc']
# [u'New York, NY', u'New York, NY', u'New York, NY', u'New York, NY 10002(Lower East Side area)', u'New York, NY', u'New York, NY', u'New York, NY 10105(Midtown area)', u'New York, NY', u'New York, NY 10010(Gramercy area)', u'New York, NY', u'New York, NY 10011(Chelsea area)', u'New York State', u'New York, NY', u'New York, NY', u'New York, NY']
# [u'DataScientist- Monitoring & Anomaly Detection Platform', u'DataScientist', u'Quantitative Analyst, AVP', u'Statistician', u'Machine Learning Engineer', u'SeniorDataEngineer for Search and Discoverability Team', u'Research Analyst', u'Mid - Senior LevelDataScientist', u'PrincipalDataScientist- Supply Chain', u'Reprise - Statistical Analyst, SEO', u'Senior Statistical Analyst', u'Digital Analyst, Research', u'Research Analyst', u'JUNIOR RESEARCHSCIENTISTMcDevitt Research Laboratory', u'DataScientist']

# %% [markdown]
# Now, to scale up our scraping, we need to accumulate more results. We can do this by examining the URL above.
#
# - "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=New+York&start=10"
#
# There are two query parameters here we can alter to collect more results, the `l=New+York` and the `start=10`. The first controls the location of the results (so we can try a different city). The second controls where in the results to start and gives 10 results (thus, we can keep incrementing by 10 to go further in the list).

# %% [markdown]
# #### Complete the following code to collect results from multiple cities and starting points.
# - Enter your city below to add it to the search
# - Remember to convert your salary to U.S. Dollars to match the other cities if the currency is different

# %%
YOUR_CITY = 'Atlanta'

# %%
url_template = "http://www.indeed.com/jobs?q=data+scientist+%24{}%2C000&l={}&start={}"
max_results_per_city = 500

rows = []

#look through each cities
for city in set(['New+York', 'Chicago', 'San+Francisco', 'Austin', 'Los+Angeles',YOUR_CITY,'Seattle']):
    #look through pages
    for start in range(0, max_results_per_city, 10):
        #parse the page
        #If the salary is set to 0, the link will search for just the term data scientist
        #If the salary is set to 100, the link will search for data scientist with $100k+ salary
        for salary in set([0,100]):
            url = url_template.format(salary,city,start)
            soup = BeautifulSoup(requests.get(url).text)
            #extracting all results
            results = soup.findAll("div", {"class": "row result"})
            #search data scienctist without any specific salary
            if salary == 0:
                for result in results:
                    if result:
                        row = {}
                        row['title'] =  extract_title_from_result(result)
                        row['company'] = extract_company_from_result(result)
                        row['salary'] = 0 #add 0s for salary under 100k
                        row['city'] = city
                        rows.append(row)
            #search data scientist with $100k salary       
            else:
                for result in results:
                    if result:
                        row = {}
                        row['title'] =  extract_title_from_result(result)
                        row['company'] = extract_company_from_result(result)
                        row['salary'] = 1 #add 1s for salary 100k and over
                        row['city'] = city
                        rows.append(row)

# %%
rows
# Out:
# [{'city': 'Chicago',
#   'company': u'Purohit Navigation',
#   'salary': 0,
#   'title': u'Market Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 0,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst - MS061333'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 0,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Sysmex',
#   'salary': 0,
#   'title': u'Scientist I, Technical Support - Sysmex Inostics'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Purohit Navigation',
#   'salary': 0,
#   'title': u'Market Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 0,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst - MS061333'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 New AWS Machine Learning- Re...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Corporate LLC',
#   'salary': 1,
#   'title': u'Software Development Engineer, Big Data- Relocation Opportun...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 Emerging AWS Machine Learnin...'},
#  {'city': 'Chicago',
#   'company': u'Consulting',
#   'salary': 1,
#   'title': u'Senior Ruby Developer'},
#  {'city': 'Chicago',
#   'company': u'CyberCoders',
#   'salary': 1,
#   'title': u'Solution Architect - Hadoop, Kafka, HDFS, Scala'},
#  {'city': 'Chicago',
#   'company': u'A2Z Development Center, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer- Relocation Opportunity'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 New AWS Machine Learning- Re...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Corporate LLC',
#   'salary': 1,
#   'title': u'Software Development Engineer, Big Data- Relocation Opportun...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 Emerging AWS Machine Learnin...'},
#  {'city': 'Chicago',
#   'company': u'Consulting',
#   'salary': 1,
#   'title': u'Senior Ruby Developer'},
#  {'city': 'Chicago',
#   'company': u'CyberCoders',
#   'salary': 1,
#   'title': u'Solution Architect - Hadoop, Kafka, HDFS, Scala'},
#  {'city': 'Chicago',
#   'company': u'A2Z Development Center, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer- Relocation Opportunity'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Senior Software Development Engineer \u2013 New AWS Machine Learn...'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 0,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Sysmex',
#   'salary': 0,
#   'title': u'Scientist I, Technical Support - Sysmex Inostics'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 New AWS Machine Learning- Re...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Corporate LLC',
#   'salary': 1,
#   'title': u'Software Development Engineer, Big Data- Relocation Opportun...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 Emerging AWS Machine Learnin...'},
#  {'city': 'Chicago',
#   'company': u'Consulting',
#   'salary': 1,
#   'title': u'Senior Ruby Developer'},
#  {'city': 'Chicago',
#   'company': u'CyberCoders',
#   'salary': 1,
#   'title': u'Solution Architect - Hadoop, Kafka, HDFS, Scala'},
#  {'city': 'Chicago',
#   'company': u'A2Z Development Center, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer- Relocation Opportunity'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 0,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst - MS061333'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 New AWS Machine Learning- Re...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Corporate LLC',
#   'salary': 1,
#   'title': u'Software Development Engineer, Big Data- Relocation Opportun...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 Emerging AWS Machine Learnin...'},
#  {'city': 'Chicago',
#   'company': u'Consulting',
#   'salary': 1,
#   'title': u'Senior Ruby Developer'},
#  {'city': 'Chicago',
#   'company': u'CyberCoders',
#   'salary': 1,
#   'title': u'Solution Architect - Hadoop, Kafka, HDFS, Scala'},
#  {'city': 'Chicago',
#   'company': u'A2Z Development Center, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer- Relocation Opportunity'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 New AWS Machine Learning- Re...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Corporate LLC',
#   'salary': 1,
#   'title': u'Software Development Engineer, Big Data- Relocation Opportun...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 Emerging AWS Machine Learnin...'},
#  {'city': 'Chicago',
#   'company': u'Consulting',
#   'salary': 1,
#   'title': u'Senior Ruby Developer'},
#  {'city': 'Chicago',
#   'company': u'CyberCoders',
#   'salary': 1,
#   'title': u'Solution Architect - Hadoop, Kafka, HDFS, Scala'},
#  {'city': 'Chicago',
#   'company': u'A2Z Development Center, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer- Relocation Opportunity'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 New AWS Machine Learning- Re...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Corporate LLC',
#   'salary': 1,
#   'title': u'Software Development Engineer, Big Data- Relocation Opportun...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 Emerging AWS Machine Learnin...'},
#  {'city': 'Chicago',
#   'company': u'Consulting',
#   'salary': 1,
#   'title': u'Senior Ruby Developer'},
#  {'city': 'Chicago',
#   'company': u'CyberCoders',
#   'salary': 1,
#   'title': u'Solution Architect - Hadoop, Kafka, HDFS, Scala'},
#  {'city': 'Chicago',
#   'company': u'A2Z Development Center, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer- Relocation Opportunity'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 New AWS Machine Learning- Re...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Corporate LLC',
#   'salary': 1,
#   'title': u'Software Development Engineer, Big Data- Relocation Opportun...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 Emerging AWS Machine Learnin...'},
#  {'city': 'Chicago',
#   'company': u'Consulting',
#   'salary': 1,
#   'title': u'Senior Ruby Developer'},
#  {'city': 'Chicago',
#   'company': u'CyberCoders',
#   'salary': 1,
#   'title': u'Solution Architect - Hadoop, Kafka, HDFS, Scala'},
#  {'city': 'Chicago',
#   'company': u'A2Z Development Center, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer- Relocation Opportunity'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 New AWS Machine Learning- Re...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Corporate LLC',
#   'salary': 1,
#   'title': u'Software Development Engineer, Big Data- Relocation Opportun...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 Emerging AWS Machine Learnin...'},
#  {'city': 'Chicago',
#   'company': u'Consulting',
#   'salary': 1,
#   'title': u'Senior Ruby Developer'},
#  {'city': 'Chicago',
#   'company': u'CyberCoders',
#   'salary': 1,
#   'title': u'Solution Architect - Hadoop, Kafka, HDFS, Scala'},
#  {'city': 'Chicago',
#   'company': u'A2Z Development Center, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer- Relocation Opportunity'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 New AWS Machine Learning- Re...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Corporate LLC',
#   'salary': 1,
#   'title': u'Software Development Engineer, Big Data- Relocation Opportun...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 Emerging AWS Machine Learnin...'},
#  {'city': 'Chicago',
#   'company': u'Consulting',
#   'salary': 1,
#   'title': u'Senior Ruby Developer'},
#  {'city': 'Chicago',
#   'company': u'CyberCoders',
#   'salary': 1,
#   'title': u'Solution Architect - Hadoop, Kafka, HDFS, Scala'},
#  {'city': 'Chicago',
#   'company': u'A2Z Development Center, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer- Relocation Opportunity'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 New AWS Machine Learning- Re...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Corporate LLC',
#   'salary': 1,
#   'title': u'Software Development Engineer, Big Data- Relocation Opportun...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 Emerging AWS Machine Learnin...'},
#  {'city': 'Chicago',
#   'company': u'Consulting',
#   'salary': 1,
#   'title': u'Senior Ruby Developer'},
#  {'city': 'Chicago',
#   'company': u'CyberCoders',
#   'salary': 1,
#   'title': u'Solution Architect - Hadoop, Kafka, HDFS, Scala'},
#  {'city': 'Chicago',
#   'company': u'A2Z Development Center, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer- Relocation Opportunity'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 0,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst - MS061333'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 New AWS Machine Learning- Re...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Corporate LLC',
#   'salary': 1,
#   'title': u'Software Development Engineer, Big Data- Relocation Opportun...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 Emerging AWS Machine Learnin...'},
#  {'city': 'Chicago',
#   'company': u'Consulting',
#   'salary': 1,
#   'title': u'Senior Ruby Developer'},
#  {'city': 'Chicago',
#   'company': u'CyberCoders',
#   'salary': 1,
#   'title': u'Solution Architect - Hadoop, Kafka, HDFS, Scala'},
#  {'city': 'Chicago',
#   'company': u'A2Z Development Center, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer- Relocation Opportunity'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 0,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst - MS061333'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 New AWS Machine Learning- Re...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Corporate LLC',
#   'salary': 1,
#   'title': u'Software Development Engineer, Big Data- Relocation Opportun...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 Emerging AWS Machine Learnin...'},
#  {'city': 'Chicago',
#   'company': u'Consulting',
#   'salary': 1,
#   'title': u'Senior Ruby Developer'},
#  {'city': 'Chicago',
#   'company': u'CyberCoders',
#   'salary': 1,
#   'title': u'Solution Architect - Hadoop, Kafka, HDFS, Scala'},
#  {'city': 'Chicago',
#   'company': u'A2Z Development Center, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer- Relocation Opportunity'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 New AWS Machine Learning- Re...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Corporate LLC',
#   'salary': 1,
#   'title': u'Software Development Engineer, Big Data- Relocation Opportun...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 Emerging AWS Machine Learnin...'},
#  {'city': 'Chicago',
#   'company': u'Consulting',
#   'salary': 1,
#   'title': u'Senior Ruby Developer'},
#  {'city': 'Chicago',
#   'company': u'CyberCoders',
#   'salary': 1,
#   'title': u'Solution Architect - Hadoop, Kafka, HDFS, Scala'},
#  {'city': 'Chicago',
#   'company': u'A2Z Development Center, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer- Relocation Opportunity'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst - MS061333'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 New AWS Machine Learning- Re...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Corporate LLC',
#   'salary': 1,
#   'title': u'Software Development Engineer, Big Data- Relocation Opportun...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 Emerging AWS Machine Learnin...'},
#  {'city': 'Chicago',
#   'company': u'Consulting',
#   'salary': 1,
#   'title': u'Senior Ruby Developer'},
#  {'city': 'Chicago',
#   'company': u'CyberCoders',
#   'salary': 1,
#   'title': u'Solution Architect - Hadoop, Kafka, HDFS, Scala'},
#  {'city': 'Chicago',
#   'company': u'A2Z Development Center, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer- Relocation Opportunity'},
#  {'city': 'Chicago',
#   'company': u'Sysmex',
#   'salary': 0,
#   'title': u'Scientist I, Technical Support - Sysmex Inostics'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 0,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst - MS061333'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 New AWS Machine Learning- Re...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Corporate LLC',
#   'salary': 1,
#   'title': u'Software Development Engineer, Big Data- Relocation Opportun...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 Emerging AWS Machine Learnin...'},
#  {'city': 'Chicago',
#   'company': u'Consulting',
#   'salary': 1,
#   'title': u'Senior Ruby Developer'},
#  {'city': 'Chicago',
#   'company': u'CyberCoders',
#   'salary': 1,
#   'title': u'Solution Architect - Hadoop, Kafka, HDFS, Scala'},
#  {'city': 'Chicago',
#   'company': u'A2Z Development Center, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer- Relocation Opportunity'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Amazon Corporate LLC',
#   'salary': 1,
#   'title': u'Software Development Engineer, Big Data- Relocation Opportun...'},
#  {'city': 'Chicago',
#   'company': u'Consulting',
#   'salary': 1,
#   'title': u'Senior Ruby Developer'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 New AWS Machine Learning- Re...'},
#  {'city': 'Chicago',
#   'company': u'CyberCoders',
#   'salary': 1,
#   'title': u'Solution Architect - Hadoop, Kafka, HDFS, Scala'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 Emerging AWS Machine Learnin...'},
#  {'city': 'Chicago',
#   'company': u'A2Z Development Center, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer- Relocation Opportunity'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 0,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst - MS061333'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 New AWS Machine Learning- Re...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Corporate LLC',
#   'salary': 1,
#   'title': u'Software Development Engineer, Big Data- Relocation Opportun...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 Emerging AWS Machine Learnin...'},
#  {'city': 'Chicago',
#   'company': u'Consulting',
#   'salary': 1,
#   'title': u'Senior Ruby Developer'},
#  {'city': 'Chicago',
#   'company': u'CyberCoders',
#   'salary': 1,
#   'title': u'Solution Architect - Hadoop, Kafka, HDFS, Scala'},
#  {'city': 'Chicago',
#   'company': u'A2Z Development Center, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer- Relocation Opportunity'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 0,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst - MS061333'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 New AWS Machine Learning- Re...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Corporate LLC',
#   'salary': 1,
#   'title': u'Software Development Engineer, Big Data- Relocation Opportun...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 Emerging AWS Machine Learnin...'},
#  {'city': 'Chicago',
#   'company': u'Consulting',
#   'salary': 1,
#   'title': u'Senior Ruby Developer'},
#  {'city': 'Chicago',
#   'company': u'CyberCoders',
#   'salary': 1,
#   'title': u'Solution Architect - Hadoop, Kafka, HDFS, Scala'},
#  {'city': 'Chicago',
#   'company': u'A2Z Development Center, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer- Relocation Opportunity'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 0,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst - MS061333'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 New AWS Machine Learning- Re...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Corporate LLC',
#   'salary': 1,
#   'title': u'Software Development Engineer, Big Data- Relocation Opportun...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 Emerging AWS Machine Learnin...'},
#  {'city': 'Chicago',
#   'company': u'Consulting',
#   'salary': 1,
#   'title': u'Senior Ruby Developer'},
#  {'city': 'Chicago',
#   'company': u'CyberCoders',
#   'salary': 1,
#   'title': u'Solution Architect - Hadoop, Kafka, HDFS, Scala'},
#  {'city': 'Chicago',
#   'company': u'A2Z Development Center, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer- Relocation Opportunity'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 0,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Sysmex',
#   'salary': 0,
#   'title': u'Scientist I, Technical Support - Sysmex Inostics'},
#  {'city': 'Chicago',
#   'company': u'Ginas Tech Jobs',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 New AWS Machine Learning- Re...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Corporate LLC',
#   'salary': 1,
#   'title': u'Software Development Engineer, Big Data- Relocation Opportun...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 Emerging AWS Machine Learnin...'},
#  {'city': 'Chicago',
#   'company': u'Consulting',
#   'salary': 1,
#   'title': u'Senior Ruby Developer'},
#  {'city': 'Chicago',
#   'company': u'CyberCoders',
#   'salary': 1,
#   'title': u'Solution Architect - Hadoop, Kafka, HDFS, Scala'},
#  {'city': 'Chicago',
#   'company': u'A2Z Development Center, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer- Relocation Opportunity'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'ACGT, Inc.',
#   'salary': 0,
#   'title': u'Bioinformatics Analyst'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 0,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Next Step Systems',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst'},
#  {'city': 'Chicago',
#   'company': u'Cameron Craig Group',
#   'salary': 1,
#   'title': u'Application Scientist'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Quantitative Research Analyst - MS061333'},
#  {'city': 'Chicago',
#   'company': u'Parallel Partners',
#   'salary': 1,
#   'title': u'Junior Quantitative Research Analyst - MS062161'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 New AWS Machine Learning- Re...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Corporate LLC',
#   'salary': 1,
#   'title': u'Software Development Engineer, Big Data- Relocation Opportun...'},
#  {'city': 'Chicago',
#   'company': u'Amazon Web Services, Inc.',
#   'salary': 1,
#   'title': u'Software Development Engineer \u2013 Emerging AWS Machine Learnin...'},
#  {'city': 'Chicago',
# ...
#   'company': u'State Street',
#   'salary': 0,
#   'title': u'Quantitative Analyst, AVP'},
#  {'city': 'New+York',
#   'company': u'New York University College of Dentistry',
#   'salary': 0,
#   'title': u'JUNIOR RESEARCH SCIENTIST McDevitt Research Laboratory'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 1,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'Hospital for Special Surgery',
#   'salary': 1,
#   'title': u'Senior Value Scientist'},
#  {'city': 'New+York',
#   'company': u'GQR Global Markets',
#   'salary': 1,
#   'title': u'Senior Data Scientist| Machine Learning Researcher|'},
#  {'city': 'New+York',
#   'company': u'New York University College of Dentistry',
#   'salary': 0,
#   'title': u'JUNIOR RESEARCH SCIENTIST McDevitt Research Laboratory'},
#  {'city': 'New+York',
#   'company': u'AbilTo, Inc',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'GQR Global Markets',
#   'salary': 1,
#   'title': u'Senior Data Scientist| Machine Learning Researcher|'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 1,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'State Street',
#   'salary': 1,
#   'title': u'Quantitative Analyst, AVP'},
#  {'city': 'New+York',
#   'company': u'New York University College of Dentistry',
#   'salary': 0,
#   'title': u'JUNIOR RESEARCH SCIENTIST McDevitt Research Laboratory'},
#  {'city': 'New+York',
#   'company': u'AbilTo, Inc',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'GQR Global Markets',
#   'salary': 1,
#   'title': u'Senior Data Scientist| Machine Learning Researcher|'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 1,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'State Street',
#   'salary': 1,
#   'title': u'Quantitative Analyst, AVP'},
#  {'city': 'New+York',
#   'company': u'State Street',
#   'salary': 0,
#   'title': u'Quantitative Analyst, AVP'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'AbilTo, Inc',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'GQR Global Markets',
#   'salary': 1,
#   'title': u'Senior Data Scientist| Machine Learning Researcher|'},
#  {'city': 'New+York',
#   'company': u'State Street',
#   'salary': 1,
#   'title': u'Quantitative Analyst, AVP'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 1,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'Uber',
#   'salary': 0,
#   'title': u'Data Scientist - Monitoring & Anomaly Detection Platform'},
#  {'city': 'New+York',
#   'company': u'ContraFect Corporation',
#   'salary': 0,
#   'title': u'Associate Director/Senior Scientist, DMPK Drug Development (...'},
#  {'city': 'New+York',
#   'company': u'New York University College of Dentistry',
#   'salary': 0,
#   'title': u'JUNIOR RESEARCH SCIENTIST McDevitt Research Laboratory'},
#  {'city': 'New+York',
#   'company': u'GQR Global Markets',
#   'salary': 1,
#   'title': u'Senior Data Scientist| Machine Learning Researcher|'},
#  {'city': 'New+York',
#   'company': u'State Street',
#   'salary': 1,
#   'title': u'Quantitative Analyst, AVP'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 1,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'New York University College of Dentistry',
#   'salary': 0,
#   'title': u'JUNIOR RESEARCH SCIENTIST McDevitt Research Laboratory'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'AbilTo, Inc',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'GQR Global Markets',
#   'salary': 1,
#   'title': u'Senior Data Scientist| Machine Learning Researcher|'},
#  {'city': 'New+York',
#   'company': u'State Street',
#   'salary': 1,
#   'title': u'Quantitative Analyst, AVP'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 1,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'Uber',
#   'salary': 0,
#   'title': u'Data Scientist - Monitoring & Anomaly Detection Platform'},
#  {'city': 'New+York',
#   'company': u'ContraFect Corporation',
#   'salary': 0,
#   'title': u'Associate Director/Senior Scientist, DMPK Drug Development (...'},
#  {'city': 'New+York',
#   'company': u'New York University College of Dentistry',
#   'salary': 0,
#   'title': u'JUNIOR RESEARCH SCIENTIST McDevitt Research Laboratory'},
#  {'city': 'New+York',
#   'company': u'GQR Global Markets',
#   'salary': 1,
#   'title': u'Senior Data Scientist| Machine Learning Researcher|'},
#  {'city': 'New+York',
#   'company': u'State Street',
#   'salary': 1,
#   'title': u'Quantitative Analyst, AVP'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 1,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'New York University College of Dentistry',
#   'salary': 0,
#   'title': u'JUNIOR RESEARCH SCIENTIST McDevitt Research Laboratory'},
#  {'city': 'New+York',
#   'company': u'AbilTo, Inc',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'GQR Global Markets',
#   'salary': 1,
#   'title': u'Senior Data Scientist| Machine Learning Researcher|'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 1,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'State Street',
#   'salary': 1,
#   'title': u'Quantitative Analyst, AVP'},
#  {'city': 'New+York',
#   'company': u'New York University College of Dentistry',
#   'salary': 0,
#   'title': u'JUNIOR RESEARCH SCIENTIST McDevitt Research Laboratory'},
#  {'city': 'New+York',
#   'company': u'AbilTo, Inc',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'GQR Global Markets',
#   'salary': 1,
#   'title': u'Senior Data Scientist| Machine Learning Researcher|'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 1,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'State Street',
#   'salary': 1,
#   'title': u'Quantitative Analyst, AVP'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'State Street',
#   'salary': 0,
#   'title': u'Quantitative Analyst, AVP'},
#  {'city': 'New+York',
#   'company': u'AbilTo, Inc',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'State Street',
#   'salary': 1,
#   'title': u'Quantitative Analyst, AVP'},
#  {'city': 'New+York',
#   'company': u'GQR Global Markets',
#   'salary': 1,
#   'title': u'Senior Data Scientist| Machine Learning Researcher|'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 1,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'AbilTo, Inc',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'State Street',
#   'salary': 0,
#   'title': u'Quantitative Analyst, AVP'},
#  {'city': 'New+York',
#   'company': u'Uber',
#   'salary': 0,
#   'title': u'Data Scientist - Monitoring & Anomaly Detection Platform'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 1,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'GQR Global Markets',
#   'salary': 1,
#   'title': u'Senior Data Scientist| Machine Learning Researcher|'},
#  {'city': 'New+York',
#   'company': u'Uber',
#   'salary': 1,
#   'title': u'Data Scientist - Monitoring & Anomaly Detection Platform'},
#  {'city': 'New+York',
#   'company': u'New York University College of Dentistry',
#   'salary': 0,
#   'title': u'JUNIOR RESEARCH SCIENTIST McDevitt Research Laboratory'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'AbilTo, Inc',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'GQR Global Markets',
#   'salary': 1,
#   'title': u'Senior Data Scientist| Machine Learning Researcher|'},
#  {'city': 'New+York',
#   'company': u'State Street',
#   'salary': 1,
#   'title': u'Quantitative Analyst, AVP'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 1,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'New York University College of Dentistry',
#   'salary': 0,
#   'title': u'JUNIOR RESEARCH SCIENTIST McDevitt Research Laboratory'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'AbilTo, Inc',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'GQR Global Markets',
#   'salary': 1,
#   'title': u'Senior Data Scientist| Machine Learning Researcher|'},
#  {'city': 'New+York',
#   'company': u'State Street',
#   'salary': 1,
#   'title': u'Quantitative Analyst, AVP'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 1,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'State Street',
#   'salary': 0,
#   'title': u'Quantitative Analyst, AVP'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'AbilTo, Inc',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'Hospital for Special Surgery',
#   'salary': 1,
#   'title': u'Senior Value Scientist'},
#  {'city': 'New+York',
#   'company': u'State Street',
#   'salary': 1,
#   'title': u'Quantitative Analyst, AVP'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 1,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'New York University College of Dentistry',
#   'salary': 0,
#   'title': u'JUNIOR RESEARCH SCIENTIST McDevitt Research Laboratory'},
#  {'city': 'New+York',
#   'company': u'AbilTo, Inc',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'GQR Global Markets',
#   'salary': 1,
#   'title': u'Senior Data Scientist| Machine Learning Researcher|'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 1,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'State Street',
#   'salary': 1,
#   'title': u'Quantitative Analyst, AVP'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'New York University College of Dentistry',
#   'salary': 0,
#   'title': u'JUNIOR RESEARCH SCIENTIST McDevitt Research Laboratory'},
#  {'city': 'New+York',
#   'company': u'AbilTo, Inc',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'State Street',
#   'salary': 1,
#   'title': u'Quantitative Analyst, AVP'},
#  {'city': 'New+York',
#   'company': u'GQR Global Markets',
#   'salary': 1,
#   'title': u'Senior Data Scientist| Machine Learning Researcher|'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 1,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'State Street',
#   'salary': 0,
#   'title': u'Quantitative Analyst, AVP'},
#  {'city': 'New+York',
#   'company': u'AbilTo, Inc',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'Hospital for Special Surgery',
#   'salary': 1,
#   'title': u'Senior Value Scientist'},
#  {'city': 'New+York',
#   'company': u'Verizon',
#   'salary': 1,
#   'title': u'Principal Data Scientist - Supply Chain'},
#  {'city': 'New+York',
#   'company': u'ContraFect Corporation',
#   'salary': 1,
#   'title': u'Director, Toxicology Drug Development (Biologics)'},
#  {'city': 'New+York',
#   'company': u'Uber',
#   'salary': 0,
#   'title': u'Data Scientist - Monitoring & Anomaly Detection Platform'},
#  {'city': 'New+York',
#   'company': u'ContraFect Corporation',
#   'salary': 0,
#   'title': u'Associate Director/Senior Scientist, DMPK Drug Development (...'},
#  {'city': 'New+York',
#   'company': u'New York University College of Dentistry',
#   'salary': 0,
#   'title': u'JUNIOR RESEARCH SCIENTIST McDevitt Research Laboratory'},
#  {'city': 'New+York',
#   'company': u'State Street',
#   'salary': 1,
#   'title': u'Quantitative Analyst, AVP'},
#  {'city': 'New+York',
#   'company': u'GQR Global Markets',
#   'salary': 1,
#   'title': u'Senior Data Scientist| Machine Learning Researcher|'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 1,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'State Street',
#   'salary': 0,
#   'title': u'Quantitative Analyst, AVP'},
#  {'city': 'New+York',
#   'company': u'AbilTo, Inc',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'State Street',
#   'salary': 1,
#   'title': u'Quantitative Analyst, AVP'},
#  {'city': 'New+York',
#   'company': u'GQR Global Markets',
#   'salary': 1,
#   'title': u'Senior Data Scientist| Machine Learning Researcher|'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 1,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'Uber',
#   'salary': 0,
#   'title': u'Data Scientist - Monitoring & Anomaly Detection Platform'},
#  {'city': 'New+York',
#   'company': u'CLIA Toxicology Lab',
#   'salary': 0,
#   'title': u'NYS-licensed Certifying Scientist (Toxicologist)'},
#  {'city': 'New+York',
#   'company': u'New York University College of Dentistry',
#   'salary': 0,
#   'title': u'JUNIOR RESEARCH SCIENTIST McDevitt Research Laboratory'},
#  {'city': 'New+York',
#   'company': u'State Street',
#   'salary': 1,
#   'title': u'Quantitative Analyst, AVP'},
#  {'city': 'New+York',
#   'company': u'Hospital for Special Surgery',
#   'salary': 1,
#   'title': u'Senior Value Scientist'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 1,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'New York University College of Dentistry',
#   'salary': 0,
#   'title': u'JUNIOR RESEARCH SCIENTIST McDevitt Research Laboratory'},
#  {'city': 'New+York',
#   'company': u'AbilTo, Inc',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'State Street',
#   'salary': 1,
#   'title': u'Quantitative Analyst, AVP'},
#  {'city': 'New+York',
#   'company': u'GQR Global Markets',
#   'salary': 1,
#   'title': u'Senior Data Scientist| Machine Learning Researcher|'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 1,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'AbilTo, Inc',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'New York University College of Dentistry',
#   'salary': 0,
#   'title': u'JUNIOR RESEARCH SCIENTIST McDevitt Research Laboratory'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 1,
#   'title': u'Data Scientist'},
#  {'city': 'New+York',
#   'company': u'State Street',
#   'salary': 1,
#   'title': u'Quantitative Analyst, AVP'},
#  {'city': 'New+York',
#   'company': u'GQR Global Markets',
#   'salary': 1,
#   'title': u'Senior Data Scientist| Machine Learning Researcher|'},
#  {'city': 'New+York',
#   'company': u'Princeton Consulting',
#   'salary': 0,
#   'title': u'Data Scientist'},
#  ...]

# %% [markdown]
# #### Use the functions you wrote above to parse out the 4 fields - location, title, company and salary. Create a dataframe from the results with those 4 columns.

# %%
## YOUR CODE HERE

#create a dataframe
data = pd.DataFrame.from_records(rows)


#data.describe()
#data.sort_values(by='salary')

#drop duplicates but keep the last. Since there was a duplicate result for a search with the salary requirement of 100k
#one without, drop the first one and keep the last search which is for 100k.
data = data.drop_duplicates(['city','company','title'],keep='last')
data
# Out:
#                city                                   company  salary  \
# 128         Chicago                 Amazon Web Services, Inc.       1
# 470         Chicago                                    Sysmex       0
# 476         Chicago                            U.S. Air Force       0
# 489         Chicago                                ACGT, Inc.       0
# 542         Chicago                        Purohit Navigation       0
# 546         Chicago                       Cushman & Wakefield       0
# 547         Chicago                       Cameron Craig Group       0
# 550         Chicago           Skills for Chicagoland's Future       0
# 551         Chicago                         Parallel Partners       1
# 552         Chicago                           Ginas Tech Jobs       1
# 553         Chicago                         Parallel Partners       1
# 554         Chicago                         Next Step Systems       1
# 555         Chicago                 Amazon Web Services, Inc.       1
# 556         Chicago                      Amazon Corporate LLC       1
# 557         Chicago                 Amazon Web Services, Inc.       1
# 558         Chicago                                Consulting       1
# 559         Chicago                               CyberCoders       1
# 560         Chicago              A2Z Development Center, Inc.       1
# 787   San+Francisco                         Realogy Corporate       1
# 800   San+Francisco                                    Circle       1
# 808   San+Francisco                        Ford Motor Company       0
# 825   San+Francisco                                     Apple       0
# 827   San+Francisco                           Personalis, Inc       0
# 837   San+Francisco                               Acumen, LLC       0
# 838   San+Francisco                        Ford Motor Company       0
# 841   San+Francisco                                    Circle       1
# 855   San+Francisco         Alambic Investment Management, LP       0
# 856   San+Francisco                                     Apple       0
# 858   San+Francisco           Client of Protean Solutions Inc       1
# 859   San+Francisco                               CyberCoders       1
# ...             ...                                       ...     ...
# 2095        Atlanta  Flex HR, Inc. - Client is in Atlanta, GA       0
# 2096        Atlanta                         Newell Rubbermaid       1
# 2097        Atlanta                                   Verizon       1
# 2198        Seattle                                    BOEING       1
# 2368        Seattle                 Amazon Web Services, Inc.       1
# 2393        Seattle                                 Nordstrom       1
# 2394        Seattle                                  T-Mobile       1
# 2395        Seattle                                   Celgene       1
# 2397        Seattle                                    Amazon       0
# 2433        Seattle                      G2 Web Services, LLC       0
# 2434        Seattle                    DoubleDown Interactive       0
# 2435        Seattle                       Penn Schoen Berland       0
# 2436        Seattle                                    Amazon       1
# 2437        Seattle                      G2 Web Services, LLC       1
# 2438        Seattle                             Akvelon, Inc.       1
# 2439        Seattle                                  T-Mobile       1
# 2440        Seattle                                    Amazon       1
# 2441        Seattle                               CyberCoders       1
# 2442        Seattle                 Amazon Web Services, Inc.       1
# 2443        Seattle                      Amazon Corporate LLC       1
# 2444        Seattle                               Benesol Inc       1
# 2840         Austin                                    Amazon       0
# 2866         Austin                               HireStarter       0
# 2868         Austin                          Weston Solutions       0
# 2869         Austin                                    Indeed       0
# 2870         Austin                  Cambia Information Group       0
# 2871         Austin                 Amazon Web Services, Inc.       0
# 2872         Austin                      Amazon Corporate LLC       0
# 2873         Austin                  CCC Information Services       0
# 2874         Austin                                    Indeed       1
#
#                                                   title
# 128   Senior Software Development Engineer – New AWS...
# 470    Scientist I, Technical Support - Sysmex Inostics
# 476                       Biomedical Laboratory Officer
# 489                              Bioinformatics Analyst
# 542                             Market Research Analyst
# 546                         Senior Research Analyst –IL
# 547                               Application Scientist
# 550                          Research Support Assistant
# 551     Junior Quantitative Research Analyst - MS062161
# 552                       Quantitative Research Analyst
# 553            Quantitative Research Analyst - MS061333
# 554                Junior Quantitative Research Analyst
# 555   Software Development Engineer – New AWS Machin...
# 556   Software Development Engineer, Big Data- Reloc...
# 557   Software Development Engineer – Emerging AWS M...
# 558                               Senior Ruby Developer
# 559     Solution Architect - Hadoop, Kafka, HDFS, Scala
# 560   Software Development Engineer- Relocation Oppo...
# 787              Software Engineer, Data and Algorithms
# 800                                        Data Analyst
# 808                                  Research Scientist
# 825                           Software Engineer, iTunes
# 827                             Bioinformatics Engineer
# 837    Data and Policy Analyst - Statistical Programmer
# 838   Machine Learning for Autonomous Vehicles Resea...
# 841                                 Risk Data Scientist
# 855                           Data Scientist / Engineer
# 856   Software Engineer, iTunes- Big Data Play Activity
# 858                                      Data Scientist
# 859                                      Data Scientist
# ...                                                 ...
# 2095             Project Analyst - Real Estate Research
# 2096                     Senior eCommerce Data Engineer
# 2097            Principal Data Scientist - Supply Chain
# 2198             System Design & Integration Specialist
# 2368  Software Development Engineer – Emerging AWS M...
# 2393  Marketing Analytics Data Scientist - Fashion I...
# 2394                             Sr. Big Data Architect
# 2395         Postdoc Fellowship - Computational Biology
# 2397                                     Sr. Researcher
# 2433                           Principal Data Scientist
# 2434                     Senior Data Warehouse Engineer
# 2435                            Market Research Analyst
# 2436                     Business Intelligence Engineer
# 2437                     Senior Data Scientist/Engineer
# 2438                    Data Scientist/Engineer (SS774)
# 2439                                  Sr Data Scientist
# 2440                               Senior Data Engineer
# 2441                           Principal Data Scientist
# 2442  Software Development Engineer – New AWS Machin...
# 2443  Software Development Engineer, Big Data- Reloc...
# 2444                  Quality Engineer, Medical Devices
# 2840            Software Development Engineer, Big Data
# 2866                  Data Scientist (customer focused)
# 2868  Project Team Lead Needed: Project Scientist, G...
# 2869                                     Data Scientist
# 2870                            Market Research Analyst
# 2871  Software Development Engineer – New AWS Machin...
# 2872  Software Development Engineer, Big Data- Reloc...
# 2873            Sr. Java Developer - IoT Data Platforms
# 2874                                      Data Engineer
#
# [105 rows x 4 columns]

# %% [markdown]
# Lastly, we need to clean up salary data.
# 1. Some of the salaries are not yearly but hourly, these will be useful to us for now
# 2. The salaries are given as text and usually with ranges.
#
# #### Filter out the salaries that are not yearly (filter those that refer to hour)

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Write a function that takes a salary string and converts it to a number, averaging a salary range if necessary

# %%
## YOUR CODE HERE

# %% [markdown]
# ### Save your results as a CSV

# %%
## YOUR CODE HERE

data.to_csv('../assets/cleanIndeed.csv',encoding='utf-8')

# %% [markdown]
# ## Predicting salaries using Logistic Regression

# %% [markdown]
# #### Load in the the data of scraped salaries

# %%
## YOUR CODE HERE

# %% [markdown]
# #### We want to predict a binary variable - whether the salary was low or high. Compute the median salary and create a new binary variable that is true when the salary is high (above the median)

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Thought experiment: What is the baseline accuracy for this model?

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Create a Logistic Regression model to predict High/Low salary using statsmodel. Start by ONLY using the location as a feature. Display the coefficients and write a short summary of what they mean.

# %%
#create dummy variables for cities
dummy_location = pd.get_dummies(data['city'], prefix='city')
cols_to_keep = ['company', 'salary', 'title']
handCalc = data[cols_to_keep].join(dummy_location.ix[:, :])
#print handCalc.head()
#print pd.crosstab(handCalc['salary'], handCalc['city_New+York'], rownames=['salary'])

# %%
## YOUR CODE HERE
import statsmodels.api as sm
cols_to_keep = ['city', 'salary', 'title']
df = data[cols_to_keep].join(dummy_location.ix[:, 'city_Austin':])
#print df.head()
df['intercept'] = 1.0
#print df.ix[:, df.columns != 'salary']

#use statsmodels to perform logistic regression
logit = sm.Logit(df['salary'], df.ix[:,3:])
result = logit.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.612570
#          Iterations 6

# %%
dfNew = df

#make a column for prediction and use the model to get the probability
dfNew['prediction'] = result.predict(df.ix[:,3:])
threshold = 0.5

#make a column and use a threshold of 0.5(best threshold I could find) to predict whether it's 0 or 1.
dfNew['approxPredict'] = [0 if i<threshold else 1 for i in dfNew['prediction']]

#confusion matrix of the results
print pd.crosstab(dfNew['approxPredict'],dfNew['salary'], rownames=['predicted'])
# Out:
# salary      0   1
# predicted
# 0          26  13
# 1          22  44

# %%
#numerical values of the coefficients and how strongly they affect the salary compared to Atlanta(since Atlanta was dropped)
print np.exp(result.params)
params = result.params

#confidence interval of 2.5% and 97.5%
conf = result.conf_int()
conf['OR'] = params
conf.columns = ['2.5%', '97.5%', 'OR']
print np.exp(conf)
# Out:
# city_Austin           0.229167
# city_Chicago          2.880952
# city_Los+Angeles      3.666667
# city_New+York         2.566667
# city_San+Francisco    1.571429
# city_Seattle          6.416667
# intercept             0.545455
# dtype: float64
#                         2.5%      97.5%        OR
# city_Austin         0.022871   2.296252  0.229167
# city_Chicago        0.729255  11.381317  2.880952
# city_Los+Angeles    0.907483  14.815095  3.666667
# city_New+York       0.562074  11.720474  2.566667
# city_San+Francisco  0.359161   6.875442  1.571429
# city_Seattle        1.444144  28.510747  6.416667
# intercept           0.201724   1.474890  0.545455

# %% [markdown]
# In order to get a 6-figure salary, it's best to go to these cities with higher exp(coef) values.

# %% [markdown]
# #### Create a few new variables in your dataframe to represent interesting features of a job title.
# - For example, create a feature that represents whether 'Senior' is in the title
# - or whether 'Manager' is in the title.
# - Then build a new Logistic Regression model with these features. Do they add any value?

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Rebuild this model with scikit-learn.
# - You can either create the dummy features manually or use the `dmatrix` function from `patsy`
# - Remember to scale the feature variables as well!

# %%
## YOUR CODE HERE
from sklearn import linear_model

#scikit-learn logistic regression model
lm = linear_model.LogisticRegression()
#target variable/predictor is salary
y = df[['salary']]
#using all the dummy variables as predictors
X = df.ix[:,3:]

result = lm.fit(X,y)

#predicted values from the scikit-learn logistic regression model
predictions = lm.predict(X)

#plt.bar(predictions,y)
#predictions
# Out:
# /Users/SangYeob/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# #### Use cross-validation in scikit-learn to evaluate the model above.
# - Evaluate the accuracy, AUC, precision and recall of the model.
# - Discuss the differences and explain when you want a high-recall or a high-precision model in this scenario.

# %%
## YOUR CODE HERE
from sklearn.cross_validation import train_test_split
y = df.salary
X = df.ix[:,3:]

#cross validation: setting up my train sets and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

#creating a model using train sets
logReg = sm.Logit(y_train,X_train)
result = logReg.fit()
result.summary()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.595950
#          Iterations: 35
# /Users/SangYeob/anaconda/lib/python2.7/site-packages/statsmodels/base/model.py:466: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 salary   No. Observations:                   73
# Model:                          Logit   Df Residuals:                       66
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 30 Jun 2016   Pseudo R-squ.:                  0.1345
# Time:                        14:21:46   Log-Likelihood:                -43.504
# converged:                      False   LL-Null:                       -50.264
#                                         LLR p-value:                   0.03550
# ======================================================================================
#                          coef    std err          z      P>|z|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------------
# city_Austin          -25.3264   1.67e+05     -0.000      1.000     -3.28e+05  3.28e+05
# city_Chicago           0.5188      0.842      0.616      0.538        -1.132     2.170
# city_Los+Angeles       1.1474      0.839      1.368      0.171        -0.497     2.792
# city_New+York          0.3365      0.918      0.366      0.714        -1.463     2.136
# city_San+Francisco     0.3365      0.862      0.390      0.696        -1.353     2.026
# city_Seattle           1.6358      0.876      1.868      0.062        -0.081     3.352
# intercept             -0.3365      0.586     -0.575      0.566        -1.484     0.811
# ======================================================================================
# """

# %%
#the actual values and the p values from the table above shows that most of my variables doesn't mean anything
print np.exp(result.params)
params = result.params
#confidence interval for the cross validation train set model
conf = result.conf_int()
conf['OR'] = params
conf.columns = ['2.5%', '97.5%', 'OR']
print np.exp(conf)
# Out:
# city_Austin           1.002080e-11
# city_Chicago          1.680000e+00
# city_Los+Angeles      3.150000e+00
# city_New+York         1.400000e+00
# city_San+Francisco    1.400000e+00
# city_Seattle          5.133333e+00
# intercept             7.142857e-01
# dtype: float64
#                         2.5%      97.5%            OR
# city_Austin         0.000000        inf  1.002080e-11
# city_Chicago        0.322340   8.755962  1.680000e+00
# city_Los+Angeles    0.608315  16.311452  3.150000e+00
# city_New+York       0.231560   8.464334  1.400000e+00
# city_San+Francisco  0.258514   7.581786  1.400000e+00
# city_Seattle        0.922319  28.570491  5.133333e+00
# intercept           0.226704   2.250529  7.142857e-01

# %%
X_test['actualSalary'] = y_test
dfTrain = X_test
dfTrain['predictedSalary'] = result.predict(dfTrain[dfTrain.columns[0:7]])
xyz = dfTrain['predictedSalary']
threshold = 0.4
dfTrain['approxPredict'] = [0 if i<threshold else 1 for i in xyz]

#confusion matrix cross validation model
print pd.crosstab(dfTrain['approxPredict'],dfTrain['actualSalary'], rownames=['predicted'])
# Out:
# actualSalary  0   1
# predicted
# 0             7   2
# 1             8  15

# %% [markdown]
# #### Compare L1 and L2 regularization for this logistic regression model. What effect does this have on the coefficients learned?

# %%
## YOUR CODE HERE
#L1 = Lasso
#penalizes the coeffecients by dropping coefficients

# %%
## YOUR CODE HERE
#L2 = Ridge
#penalizes the coefficients by reducing the

# %% [markdown]
# #### Continue to incorporate other text features from the title or summary that you believe will predict the salary and examine their coefficients

# %% [markdown]
# #### Take ~100 scraped entries with salaries. Convert them to use with your model and predict the salary - which entries have the highest predicted salaries?

# %% [markdown]
# ### BONUS

# %% [markdown]
# #### Bonus: Use Count Vectorizer from scikit-learn to create features from the text summaries.
# - Examine using count or binary features in the model
# - Re-evaluate the logistic regression model using these. Does this improve the model performance?
# - What text features are the most valuable?

# %%
## YOUR CODE HERE

# %%
## YOUR CODE HERE

# %% [markdown]
# #### Re-test L1 and L2 regularization. You can use LogisticRegressionCV to find the optimal reguarlization parameters.
# - Re-test what text features are most valuable.
# - How do L1 and L2 change the coefficients?

# %%
## YOUR CODE HERE
